# %%
# Importiamo di default  le librerie
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
#### We import the datasets 
pokedex = pd.read_csv("pokemon_database.csv", encoding="latin-1")
region = pd.read_csv('pokemon_region.csv')
stats = pd.read_csv('pokemon_stats.csv')

# %%
print(pokedex.head())
print(region.head())
print(stats.head())
# Out:
#    Pokemon Id  Pokedex Number Pokemon Name  Classification  \
# 0           1               1    Bulbasaur    Seed Pokemon
# 1           2               2      Ivysaur    Seed Pokemon
# 2           3               3     Venusaur    Seed Pokemon
# 3           4               3     Venusaur    Seed Pokemon
# 4           5               4   Charmander  Lizard Pokemon
#
#   Alternate Form Name  Original Pokemon ID Legendary Type Primary Type  \
# 0                 NaN                  NaN            NaN        Grass
# 1                 NaN                  NaN            NaN        Grass
# 2                 NaN                  NaN            NaN        Grass
# 3                Mega                  3.0            NaN        Grass
# 4                 NaN                  NaN            NaN         Fire
#
#   Secondary Type Primary Ability  ... Special Event Ability Description  \
# 0         Poison        Overgrow  ...                               NaN
# ...

# %%
# We print the columns 
print(pokedex.columns)
print(region.columns)
print(stats.columns)
# Out:
# Index(['Pokemon Id', 'Pokedex Number', 'Pokemon Name', 'Classification',
#        'Alternate Form Name', 'Original Pokemon ID', 'Legendary Type',
#        'Primary Type', 'Secondary Type', 'Primary Ability',
#        'Primary Ability Description', 'Secondary Ability',
#        'Secondary Ability Description', 'Hidden Ability',
#        'Hidden Ability Description', 'Special Event Ability',
#        'Special Event Ability Description', 'Base Happiness',
#        'Game(s) of Origin', 'Experience Growth', 'Experience Yield',
#        'Primary Egg Group', 'Secondary Egg Group', 'Egg Cycle Count',
#        'Pre-Evolution Pokemon Id', 'Evolution Details'],
#       dtype='str')
# Index(['games', 'region'], dtype='str')
# Index(['Pokedex Number', 'Health Stat', 'Attack Stat', 'Defense Stat',
#        'Special Attack Stat', 'Special Defense Stat', 'Speed Stat',
#        'Base Stat Total', 'Health EV', 'Attack EV', 'Defense EV',
# ...

# %%
#### We look at hte length 
print(len(pokedex))
print(len(region))
print(len(stats))
# Out:
# 1076
# 16
# 1076

# %%
#pokedex['Game(s) of Origin']
#print(stats['Experience Growth Total'])
print(pokedex['Pokedex Number'])
print(stats['Pokedex Number'])
# Out:
# 0         1
# 1         2
# 2         3
# 3         3
# 4         4
#        ...
# 1071    892
# 1072    896
# 1073    897
# 1074    898
# 1075    898
# Name: Pokedex Number, Length: 1076, dtype: int64
# 0         1
# 1         2
# 2         3
# 3         3
# 4         4
#        ...
# 1071    892
# 1072    896
# 1073    897
# 1074    898
# 1075    898
# Name: Pokedex Number, Length: 1076, dtype: int64

# %%
colonne_pokedex = ['Pokemon Id', 'Pokedex Number', 'Pokemon Name']
colonne_stats = ['Pokemon Id', 'Pokedex Number', 'Pokemon Name']

regione = 'Kanto'
squadra_capopalestra = ['Bulbasaur','Pikachu','Pidgeot','Rattata','Makey']

nostra_squadra 
pokedex_1 = pokedex[]

# %%
stats.corr()
# Out:
#                          Pokedex Number  Health Stat  Attack Stat  \
# Pokedex Number                 1.000000     0.130112     0.138122
# Health Stat                    0.130112     1.000000     0.451392
# Attack Stat                    0.138122     0.451392     1.000000
# Defense Stat                   0.113679     0.301644     0.459626
# Special Attack Stat            0.103813     0.361051     0.360348
# Special Defense Stat           0.083669     0.390005     0.259641
# Speed Stat                     0.023198     0.171722     0.362069
# Base Stat Total                0.148058     0.649842     0.732975
# Health EV                     -0.022264     0.509178    -0.019393
# Attack EV                      0.091856     0.185366     0.591344
# Defense EV                     0.039239    -0.056110     0.020724
# Special Attack EV              0.016531     0.049796     0.016764
# Special Defense EV            -0.018333    -0.012402    -0.151795
# ...
